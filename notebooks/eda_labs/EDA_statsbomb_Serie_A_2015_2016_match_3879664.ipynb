# %% [markdown]
# # 🔬 Master EDA Laboratory
# *Dataset: `statsbomb_Serie_A_2015_2016_match_3879664.csv`*
#
# This notebook contains the complete pipeline for Exploratory Data Analysis, Outlier Detection, Scaling, Feature Selection, and Clustering based on your standard methodology.
#
# **INSTRUCTIONS:** Read through the cells, modify the `TARGET_COL` where requested, and run the pipeline.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import sys
import warnings
warnings.filterwarnings('ignore')

from sklearn.preprocessing import LabelEncoder, StandardScaler, MinMaxScaler, MaxAbsScaler
from sklearn.cluster import KMeans
from sklearn.ensemble import ExtraTreesClassifier, RandomForestClassifier
from sklearn.feature_selection import SelectKBest, chi2, RFE

# System path for database uploader
sys.path.append('../../') 
from scripts.db_uploader import upload_to_postgres

# %%
# 1. LOAD DATA
df = pd.read_csv('../../data/raw/statsbomb_Serie_A_2015_2016_match_3879664.csv', low_memory=False)
print(f'✅ Dataset loaded: {df.shape[0]} rows, {df.shape[1]} columns')
df.head(3)
# Out:
# ✅ Dataset loaded: 3406 rows, 93 columns
#   ball_receipt_outcome ball_recovery_offensive ball_recovery_recovery_failure  \
# 0                  NaN                     NaN                            NaN
# 1                  NaN                     NaN                            NaN
# 2                  NaN                     NaN                            NaN
#
#   block_offensive carry_end_location clearance_aerial_won clearance_body_part  \
# 0             NaN                NaN                  NaN                 NaN
# 1             NaN                NaN                  NaN                 NaN
# 2             NaN                NaN                  NaN                 NaN
#
#   clearance_head clearance_left_foot clearance_right_foot  ...  \
# 0            NaN                 NaN                  NaN  ...
# 1            NaN                 NaN                  NaN  ...
# 2            NaN                 NaN                  NaN  ...
#
#   substitution_outcome substitution_outcome_id substitution_replacement  \
# 0                  NaN                     NaN                      NaN
# 1                  NaN                     NaN                      NaN
# 2                  NaN                     NaN                      NaN
#
#   substitution_replacement_id  \
# 0                         NaN
# 1                         NaN
# 2                         NaN
#
#                                              tactics       team  team_id  \
# 0  {'formation': 4141, 'lineup': [{'player': {'id...  Sampdoria      234
# 1  {'formation': 442, 'lineup': [{'player': {'id'...    Palermo     2256
# 2                                                NaN  Sampdoria      234
#
#       timestamp         type under_pressure
# 0  00:00:00.000  Starting XI            NaN
# 1  00:00:00.000  Starting XI            NaN
# 2  00:00:00.000   Half Start            NaN
#
# [3 rows x 93 columns]

# %% [markdown]
# ## Phase 1: Basic Exploration & Imputation

# %%
# Data overview
df.info()
print('\n--- Missing Values ---')
print(df.isnull().sum())

# Statistical summary
display(df.describe().round(2))

# Clean Empty Structures
df.dropna(how='all', axis=1, inplace=True)
df.dropna(how='all', axis=0, inplace=True)
df.fillna(0, inplace=True) # Basic imputation (customize as needed)
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3406 entries, 0 to 3405
# Data columns (total 93 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   ball_receipt_outcome            204 non-null    str
#  1   ball_recovery_offensive         1 non-null      object
#  2   ball_recovery_recovery_failure  8 non-null      object
#  3   block_offensive                 1 non-null      object
#  4   carry_end_location              713 non-null    str
#  5   clearance_aerial_won            9 non-null      object
#  6   clearance_body_part             56 non-null     str
#  7   clearance_head                  29 non-null     object
#  8   clearance_left_foot             6 non-null      object
#  9   clearance_right_foot            21 non-null     object
#  10  counterpress                    96 non-null     object
#  11  dribble_nutmeg                  3 non-null      object
#  12  dribble_outcome                 27 non-null     str
#  13  dribble_overrun                 2 non-null      object
#  14  duel_outcome                    40 non-null     str
#  15  duel_type                       73 non-null     str
#  16  duration                        2504 non-null   float64
#  17  foul_committed_advantage        7 non-null      object
#  18  foul_committed_card             6 non-null      str
#  19  foul_committed_offensive        4 non-null      object
#  20  foul_committed_type             5 non-null      str
#  21  foul_won_advantage              7 non-null      object
#  22  foul_won_defensive              9 non-null      object
#  23  goalkeeper_body_part            10 non-null     str
#  24  goalkeeper_end_location         16 non-null     str
#  25  goalkeeper_outcome              18 non-null     str
#  26  goalkeeper_position             28 non-null     str
#  27  goalkeeper_technique            12 non-null     str
#  28  goalkeeper_type                 34 non-null     str
#  29  id                              3406 non-null   str
#  30  index                           3406 non-null   int64
#  31  injury_stoppage_in_chain        1 non-null      object
#  32  interception_outcome            23 non-null     str
#  33  location                        3375 non-null   str
#  34  match_id                        3406 non-null   int64
#  35  minute                          3406 non-null   int64
#  36  off_camera                      53 non-null     object
#  37  out                             29 non-null     object
#  38  pass_aerial_won                 22 non-null     object
#  39  pass_angle                      913 non-null    float64
#  40  pass_assisted_shot_id           21 non-null     str
#  41  pass_body_part                  856 non-null    str
#  42  pass_cross                      25 non-null     object
#  43  pass_cut_back                   6 non-null      object
#  44  pass_deflected                  1 non-null      object
#  45  pass_end_location               913 non-null    str
#  46  pass_goal_assist                2 non-null      object
#  47  pass_height                     913 non-null    str
#  48  pass_inswinging                 3 non-null      object
#  49  pass_length                     913 non-null    float64
#  50  pass_miscommunication           1 non-null      object
#  51  pass_no_touch                   2 non-null      object
#  52  pass_outcome                    214 non-null    str
#  53  pass_outswinging                2 non-null      object
#  54  pass_recipient                  904 non-null    str
#  55  pass_recipient_id               904 non-null    float64
#  56  pass_shot_assist                19 non-null     object
#  57  pass_straight                   1 non-null      object
#  58  pass_switch                     24 non-null     object
#  59  pass_technique                  9 non-null      str
#  60  pass_through_ball               3 non-null      object
#  61  pass_type                       219 non-null    str
#  62  period                          3406 non-null   int64
#  63  play_pattern                    3406 non-null   str
#  64  player                          3391 non-null   str
#  65  player_id                       3391 non-null   float64
#  66  position                        3391 non-null   str
#  67  possession                      3406 non-null   int64
#  68  possession_team                 3406 non-null   str
#  69  possession_team_id              3406 non-null   int64
#  70  related_events                  3233 non-null   str
#  71  second                          3406 non-null   int64
#  72  shot_aerial_won                 2 non-null      object
#  73  shot_body_part                  28 non-null     str
#  74  shot_end_location               28 non-null     str
#  75  shot_first_time                 8 non-null      object
#  76  shot_freeze_frame               28 non-null     str
#  77  shot_key_pass_id                21 non-null     str
#  78  shot_one_on_one                 2 non-null      object
#  79  shot_outcome                    28 non-null     str
#  80  shot_statsbomb_xg               28 non-null     float64
#  81  shot_technique                  28 non-null     str
#  82  shot_type                       28 non-null     str
#  83  substitution_outcome            6 non-null      str
#  84  substitution_outcome_id         6 non-null      float64
#  85  substitution_replacement        6 non-null      str
#  86  substitution_replacement_id     6 non-null      float64
#  87  tactics                         5 non-null      str
#  88  team                            3406 non-null   str
#  89  team_id                         3406 non-null   int64
#  90  timestamp                       3406 non-null   str
#  91  type                            3406 non-null   str
#  92  under_pressure                  671 non-null    object
# dtypes: float64(8), int64(8), object(34), str(43)
# memory usage: 3.2+ MB
#
# --- Missing Values ---
# ball_receipt_outcome              3202
# ball_recovery_offensive           3405
# ball_recovery_recovery_failure    3398
# block_offensive                   3405
# carry_end_location                2693
#                                   ...
# team                                 0
# team_id                              0
# timestamp                            0
# type                                 0
# under_pressure                    2735
# Length: 93, dtype: int64
#        duration    index   match_id   minute  pass_angle  pass_length  \
# count   2504.00  3406.00     3406.0  3406.00      913.00       913.00
# mean       1.25  1703.50  3879664.0    42.24        0.02        22.26
# std        1.35   983.37        0.0    26.05        1.50        14.92
# min        0.00     1.00  3879664.0     0.00       -3.12         1.70
# 25%        0.16   852.25  3879664.0    20.00       -1.13        12.21
# 50%        1.00  1703.50  3879664.0    40.00       -0.03        18.10
# 75%        1.82  2554.75  3879664.0    61.00        1.24        27.56
# max       14.63  3406.00  3879664.0    94.00        3.14        86.23
#
#        pass_recipient_id   period  player_id  possession  possession_team_id  \
# count             904.00  3406.00    3391.00     3406.00             3406.00
# mean            38814.45     1.46   35603.65       93.05             1035.44
# std             88558.75     0.50   83265.48       55.36              989.19
# min              5584.00     1.00    5584.00        1.00              234.00
# 25%              7012.00     1.00    7012.00       45.00              234.00
# 50%             16586.00     1.00   10032.00       91.00              234.00
# 75%             27595.00     2.00   27595.00      136.00             2256.00
# max            387417.00     2.00  387417.00      192.00             2256.00
#
#         second  shot_statsbomb_xg  substitution_outcome_id  \
# count  3406.00              28.00                      6.0
# mean     29.08               0.08                    103.0
# std      17.50               0.08                      0.0
# min       0.00               0.00                    103.0
# 25%      14.00               0.03                    103.0
# 50%      29.00               0.06                    103.0
# 75%      44.75               0.09                    103.0
# max      59.00               0.37                    103.0
#
#        substitution_replacement_id  team_id
# count                         6.00  3406.00
# mean                      20856.67  1126.27
# std                       13259.26  1004.15
# min                        6334.00   234.00
# 25%                       10243.50   234.00
# 50%                       19582.00   234.00
# 75%                       29038.25  2256.00
# max                       40321.00  2256.00
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 12
#       8
#       9 # Clean Empty Structures
#      10 df.dropna(how='all', axis=1, inplace=True)
#      11 df.dropna(how='all', axis=0, inplace=True)
# ---> 12 df.fillna(0, inplace=True) # Basic imputation (customize as needed)
#
# File c:\Users\salva\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:7159, in NDFrame.fillna(self, value, axis, inplace, limit)
#    7155             if axis == 1:
#    7156                 result = self.T.fillna(value=value, limit=limit).T
#    7157                 new_data = result._mgr
#    7158             else:
# -> 7159                 new_data = self._mgr.fillna(value=value, limit=limit, inplace=inplace)
#    7160         elif isinstance(value, ABCDataFrame) and self.ndim == 2:
#    7161             new_data = self.where(self.notna(), value)._mgr
#    7162         else:
#
# File c:\Users\salva\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\managers.py:461, in BaseBlockManager.fillna(self, value, limit, inplace)
#     457 if limit is not None:
#     458     # Do this validation even if we go through one of the no-op paths
#     459     limit = libalgos.validate_limit(None, limit=limit)
# --> 461 return self.apply(
#     462     "fillna",
#     463     value=value,
#     464     limit=limit,
#     465     inplace=inplace,
#     466 )
#
# File c:\Users\salva\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\managers.py:445, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     443         applied = b.apply(f, **kwargs)
#     444     else:
# --> 445         applied = getattr(b, f)(**kwargs)
#     446     result_blocks = extend_blocks(applied, result_blocks)
#     448 out = type(self).from_blocks(result_blocks, [ax.view() for ax in self.axes])
#
# File c:\Users\salva\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\blocks.py:1893, in ExtensionBlock.fillna(self, value, limit, inplace)
#    1891     if isinstance(self.dtype, IntervalDtype) and limit is not None:
#    1892         raise ValueError("limit must be None")
# -> 1893     return super().fillna(
#    1894         value=value,
#    1895         limit=limit,
#    1896         inplace=inplace,
#    1897     )
#    1898 if self._can_hold_na and not self.values._hasna:
#    1899     refs = self.refs
#
# File c:\Users\salva\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\blocks.py:1342, in Block.fillna(self, value, limit, inplace)
#    1339     mask[mask.cumsum(self.values.ndim - 1) > limit] = False
#    1341 if inplace:
# -> 1342     nbs = self.putmask(mask.T, value)
#    1343 else:
#    1344     nbs = self.where(value, ~mask.T)
#
# File c:\Users\salva\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\blocks.py:1774, in EABackedBlock.putmask(self, mask, new)
#    1770     values = values.T
#    1772 try:
#    1773     # Caller is responsible for ensuring matching lengths
# -> 1774     values._putmask(mask, new)
#    1775 except OutOfBoundsDatetime:
#    1776     raise
#
# File c:\Users\salva\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\arrays\base.py:2585, in ExtensionArray._putmask(self, mask, value)
#    2582 else:
#    2583     val = value
# -> 2585 self[mask] = val
#
# File c:\Users\salva\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\arrays\arrow\array.py:2237, in ArrowExtensionArray.__setitem__(self, key, value)
#    2234     key = key[0]
#    2236 key = check_array_indexer(self, key)
# -> 2237 value = self._maybe_convert_setitem_value(value)
#    2239 if com.is_null_slice(key):
#    2240     # fast path (GH50248)
#    2241     if (
#    2242         isinstance(value, (pa.Array, pa.ChunkedArray))
#    2243         and value.type == self._pa_array.type
#    2244         and len(value) == len(self)
#    2245     ):
#
# File c:\Users\salva\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\arrays\string_arrow.py:287, in ArrowStringArray._maybe_convert_setitem_value(self, value)
#     285         value = None
#     286     elif not isinstance(value, str):
# --> 287         raise TypeError(
#     288             f"Invalid value '{value}' for dtype 'str'. Value should be a "
#     289             f"string or missing value, got '{type(value).__name__}' instead."
#     290         )
#     291 elif isinstance(value, type(self)):
#     292     pass
#
# TypeError: Invalid value '0' for dtype 'str'. Value should be a string or missing value, got 'int' instead.

# %% [markdown]
# ## Phase 2: Encoding & Datetime Parsing

# %%
# Auto-detect and parse datetime columns
for col in df.columns:
    if 'date' in col.lower():
        try:
            df[col] = pd.to_datetime(df[col])
            print(f'✅ Converted {col} to datetime.')
        except:
            pass

# Categorical Variables Encoding
cat_cols = df.select_dtypes(include=['object', 'bool']).columns.tolist()
for col in cat_cols:
    unique_vals = [str(x).lower() for x in df[col].unique()]
    if 'true' in unique_vals or 'false' in unique_vals:
        df[col] = df[col].map({True: 1, False: 0, 'True': 1, 'False': 0, '1': 1, '0': 0}).fillna(0).astype(int)
    else:
        df[col] = df[col].astype(str)
        df[col+'_encoded'] = LabelEncoder().fit_transform(df[col])
print('✅ Encoding completed.')
# Out:
# ✅ Encoding completed.

# %% [markdown]
# ## Phase 3: Visualizations & Correlation

# %%
numerical_data = df.select_dtypes(include=np.number)

# 3.1 Data Distribution (Histograms)
print('--- Data Distributions ---')
num_cols_to_plot = min(5, len(numerical_data.columns)) # Plot first 5 numeric cols to avoid clutter
for col in numerical_data.columns[:num_cols_to_plot]:
    plt.figure(figsize=(6, 3))
    sns.histplot(df[col], kde=True, bins=30, color='skyblue')
    plt.title(f'Distribution of {col}')
    plt.show()

# 3.2 Correlation Matrix Heatmap
plt.figure(figsize=(12, 10))
sns.heatmap(numerical_data.corr(), annot=False, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix')
plt.show()
# Out:
# --- Data Distributions ---

# %% [markdown]
# ## Phase 4: Outlier Detection & Treatment

# %%
# 4.1 Visual Outlier Detection (Boxplots)
print('--- Outlier Boxplots ---')
for col in numerical_data.columns[:num_cols_to_plot]:
    plt.figure(figsize=(6, 2))
    sns.boxplot(x=df[col], color='lightgreen')
    plt.title(f'Boxplot of {col}')
    plt.show()

# 4.2 Outlier Treatment Functions
def remove_outliers_tukey(data, column, k=1.5):
    """Removes rows with outliers based on IQR"""
    if column not in data.columns: return data
    q1 = np.percentile(data[column].dropna(), 25)
    q3 = np.percentile(data[column].dropna(), 75)
    iqr = q3 - q1
    lower_fence = q1 - k * iqr
    upper_fence = q3 + k * iqr
    return data[(data[column] >= lower_fence) & (data[column] <= upper_fence)]

def winsorize_outliers(data, column, lower_percentile=0.05, upper_percentile=0.95):
    """Caps extreme values without deleting rows"""
    if column not in data.columns: return data
    upper_lim = data[column].quantile(upper_percentile)
    lower_lim = data[column].quantile(lower_percentile)
    data.loc[(data[column] > upper_lim), column] = upper_lim
    data.loc[(data[column] < lower_lim), column] = lower_lim
    return data

# Example Usage (Uncomment to apply):
# df = remove_outliers_tukey(df, 'price')
# df = winsorize_outliers(df, 'points')
print('✅ Outlier functions loaded.')
# Out:
# --- Outlier Boxplots ---
# ✅ Outlier functions loaded.

# %% [markdown]
# ## Phase 5: Scaling & Normalization

# %%
# Select columns to scale (excluding IDs or Target if necessary)
cols_to_scale = numerical_data.columns

# Standard Scaling (Mean=0, Variance=1)
std_scaler = StandardScaler()
# df[cols_to_scale] = std_scaler.fit_transform(df[cols_to_scale])

# Min-Max Scaling (Range 0 to 1)
mm_scaler = MinMaxScaler()
# df[cols_to_scale] = mm_scaler.fit_transform(df[cols_to_scale])

print('✅ Scalers initialized. Uncomment the desired scaler line to apply it.')
# Out:
# ✅ Scalers initialized. Uncomment the desired scaler line to apply it.

# %% [markdown]
# ## Phase 6: Feature Selection & Clustering

# %%
# --- CONFIGURATION ---
# IMPORTANT: Set your main target column here for Feature Selection analysis
TARGET_COL = 'your_target_column_here'  # Replace with your actual column name

# %%
print('--- Machine Learning Tools ---')

# 6.1 Feature Importance (Tree-based)
if TARGET_COL in df.columns:
    try:
        X = df.select_dtypes(include=np.number).drop(TARGET_COL, axis=1).fillna(0)
        y = df[TARGET_COL].fillna(0)
        model = RandomForestClassifier(n_estimators=50, random_state=42)
        model.fit(X, y)
        
        feat_importances = pd.Series(model.feature_importances_, index=X.columns)
        plt.figure(figsize=(10, 5))
        feat_importances.nlargest(10).plot(kind='barh', color='teal')
        plt.title('Top 10 Most Important Features')
        plt.show()
    except Exception as e:
        print(f'Feature Importance skipped: {e}')
else:
    print(f'⚠️ Target column "{TARGET_COL}" not found. Update configuration in Cell 1 to run Feature Selection.')

# 6.2 K-Means Clustering Example
# Example: Clustering users/players based on 2 numeric columns
def apply_kmeans(data, cols_for_clustering, num_clusters=3):
    if all(c in data.columns for c in cols_for_clustering):
        kmeans = KMeans(n_clusters=num_clusters, random_state=42, n_init=10)
        data['cluster_id'] = kmeans.fit_predict(data[cols_for_clustering].fillna(0))
        print(f'✅ K-Means applied. Created {num_clusters} clusters.')
        return data
    return data

# df = apply_kmeans(df, ['numeric_col_1', 'numeric_col_2'], num_clusters=3)

# %% [markdown]
# ## 🚀 Phase 7: Finish EDA & Upload to Database
# Execute this cell to upload the polished DataFrame to your PostgreSQL (Silver Layer).

# %%
# Ensure the database connection script has the correct password configured in your .env file
upload_to_postgres(df, table_name='statsbomb_serie_a_2015_2016_match_3879664_clean')
